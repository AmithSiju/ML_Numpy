# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Draw a line in a diagram from position (1,3) to (2,10) then to (6,12) and finally to position (18,20). Mark each point with a beautiful green colour and set line colour to red and line style dotted)

# %%
x = [1,2,6,18]
y = [3,10,12,20]
plt.plot(x,y,'red',marker='.',markerfacecolor='green',markeredgecolor='green',markersize=20,label='graph')
plt.grid(True)
plt.show()

# %%
2. Plot the following data (Table)

# %%
x = [12,14,16,18,20,22,24]
y = [100,200,250,400,300,450,500]
plt.plot(x,y)
plt.xlabel("Temperature in °C")
plt.ylabel("Sales")
plt.show()

# %%
3. Write a Python Program to draw a line using given axis values take from a text file with a suitable label in x-axis, y-axis and title.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data.txt')
x = data[:, 0]
y = data[:, 1]

plt.plot(x, y)

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Graph from Text File Data')

plt.show()
np.savetxt('output.txt', data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 data = np.loadtxt('data.txt')
#       5 x = data[:, 0]
#       6 y = data[:, 1]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...

# %% [markdown]
# 4. Write a Python program to plot two or more lines on the same plot with suitable legends of each line.

# %%
x1 = np.array([2002,2004,2006,2008,2010])
x2 = np.array([100,150,9,31,240])
x3 = np.array([10,26,50,1,34])
plt.title("Test Run")
plt.plot(x1,x2,'r',label='x1-x2')
plt.plot(x1,x3, label='x1-x3')
# plt.legend()

# %%
5. Write a python program to create multiple plots.

# %%
a = np.arange(0,10,0.1)
b = np.sin(a)
c = np.cos(a)
plt.subplot(2,1,2)
plt.plot(a,b)
plt.title("Sin Wave")
plt.subplot(2,2,2)
plt.plot(a,c)
plt.title("Cos Wave")

plt.subplot(2,2,1)
plt.plot(b,c)
plt.title("Wave")
# Out:
# Text(0.5, 1.0, 'Wave')

# %% [markdown]
# 6. i) Write a Python program to display a bar chart of the popularity of programming Languages.
# ii)Write a Python programming to display a horizontal bar chart of the popularity of programming Lnaguages(Red bar chart)
# iii) Write a Python program to dispaly a bar chart of the popularity of programming languages(diffrent color for each bar)

# %%
x =['Java','Python','PHP','JS','C#','C++']
y = [22.2,17.6,8.8,8,77,6.7]
plt.bar(x,y, color='g')
# Out:
# <BarContainer object of 6 artists>

# %%
x =['Java','Python','PHP','JS','C#','C++']
y = [22.2,17.6,8.8,8,77,6.7]
plt.barh(x,y, color='r')
# Out:
# <BarContainer object of 6 artists>

# %%
x =['Java','Python','PHP','JS','C#','C++']
y = [22.2,17.6,8.8,8,77,6.7]
plt.bar(x[0],y[0], color='c')
plt.bar(x[1],y[1], color='r')
plt.bar(x[2],y[2], color='b')
plt.bar(x[3],y[3], color='g')
plt.bar(x[4],y[4], color='orange')
plt.bar(x[5],y[5], color='m')
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# 7.Write a Python program to create a bar plot of score by group and gender. Use multiple X values on the same chart for men

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data to plot
n_groups = 5
men_means = (22, 30, 35, 35, 26)
women_means = (25, 32, 30, 35, 29)

# Create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, men_means, bar_width, alpha=opacity, color='b', label='Men')
rects2 = plt.bar(index + bar_width, women_means, bar_width, alpha=opacity, color='r', label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(index + bar_width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend()

plt.tight_layout()
plt.show()
